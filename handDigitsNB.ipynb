# %%
import sys

sys.path.append('/home/radlr/anaconda3/envs/lVGPU2/lib/python3.6/site-packages')

#hint from https://stackoverflow.com/questions/19876079/opencv-cannot-find-module-cv2

# math etc.
from scipy import misc
import numpy as np

#plotting
import matplotlib as mpl
from matplotlib import pyplot as plt

#image functions, esp. resizing
import cv2
#directory functions
import os

#Data management

import pandas as pd

# %%
# The full-size simulated RGB image stack is the training target
# now to create an input stack using the cuttleVision function
myDimX = 64
myDimY = 48

myTargets = []
myImgs = []

#all of the images in this directory are labelled '0'
myMiniDir = os.listdir('./toyData/0')


#myC = 0 
for k in myMiniDir:
    #myC = myC+1 

    #print(k)
    
    myImg = cv2.imread('./toyData/0/'+str(k))
    myImg = cv2.cvtColor(myImg, cv2.COLOR_BGR2RGB)
    myResImg = cv2.resize(myImg,(myDimX,myDimY))
    myTargets.append(0.0)
    myImgs.append(myResImg)
    
    
plt.figure()
plt.imshow(myImg)
plt.figure()
plt.imshow(myImgs[len(myImgs)-1])
plt.show()
print("Target vector shape: ", np.shape(myTargets[0]))
print("Training vector shape: ", np.shape(myImgs[0]))
# Out:
# Target vector shape:  ()
# Training vector shape:  (48, 64, 3)

# %%
#all of the images in this directory are labelled '1'
myMiniDir = os.listdir('./toyData/1')


#myC = 0 
for k in myMiniDir:
    #myC = myC+1 

    #print(k)
    
    myImg = cv2.imread('./toyData/1/'+str(k))
    myImg = cv2.cvtColor(myImg, cv2.COLOR_BGR2RGB)
    myResImg = cv2.resize(myImg,(myDimX,myDimY))
    myTargets.append(1.0)
    myImgs.append(myResImg)
    
    
plt.figure()
plt.imshow(myImg)
plt.figure()
plt.imshow(myImgs[len(myImgs)-1])
plt.show()
print("Target vector shape: ", np.shape(myTargets[0]))
print("Training vector shape: ", np.shape(myImgs[0]))
# Out:
# Target vector shape:  ()
# Training vector shape:  (48, 64, 3)

# %%
#all of the images in this directory are labelled '2'
myMiniDir = os.listdir('./toyData/2')


#myC = 0 
for k in myMiniDir:
    #myC = myC+1 

    #print(k)
    
    myImg = cv2.imread('./toyData/2/'+str(k))
    myImg = cv2.cvtColor(myImg, cv2.COLOR_BGR2RGB)
    myResImg = cv2.resize(myImg,(myDimX,myDimY))
    myTargets.append(2.0)
    myImgs.append(myResImg)
    
    
plt.figure()
plt.imshow(myImg)
plt.figure()
plt.imshow(myImgs[len(myImgs)-1])
plt.show()
print("Target vector shape: ", np.shape(myTargets[0]))
print("Training vector shape: ", np.shape(myImgs[0]))
# Out:
# Target vector shape:  ()
# Training vector shape:  (48, 64, 3)

# %%
#all of the images in this directory are labelled '0'
myMiniDir = os.listdir('./toyData/3')


#myC = 0 
for k in myMiniDir:
    #myC = myC+1 

    #print(k)
    
    myImg = cv2.imread('./toyData/3/'+str(k))
    myImg = cv2.cvtColor(myImg, cv2.COLOR_BGR2RGB)
    myResImg = cv2.resize(myImg,(myDimX,myDimY))
    myTargets.append(3.0)
    myImgs.append(myResImg)
    
    
plt.figure()
plt.imshow(myImg)
plt.figure()
plt.imshow(myImgs[len(myImgs)-1])
plt.show()
print("Target vector shape: ", np.shape(myTargets[0]))
print("Training vector shape: ", np.shape(myImgs[0]))
# Out:
# Target vector shape:  ()
# Training vector shape:  (48, 64, 3)

# %%
print(np.shape(myImgs))
print(np.shape(myTargets))
# Out:
# (640, 48, 64, 3)
# (640,)

# %%
myImgs = np.array(myImgs)
myTargets = np.array([myTargets])

# %%
myTargets = myTargets.T

# %%
print(np.shape(myImgs))
print(np.shape(myTargets))
# Out:
# (640, 48, 64, 3)
# (640, 1)

# %%
myTargets[0]
# Out:
# array([ 0.])

# %%
mySize = np.shape(myImgs)[0] #length of training image vector

for c in range(0,mySize):
    myImg = myImgs[c,:]
    
    cv2.imwrite('./toyData/trainImgs/trainImg'+str(c)+'.tif',
                cv2.cvtColor(myImg, cv2.COLOR_BGR2RGB))
    
    if(c % 500 == 0):
        print("Saved training img number ", c)
        plt.figure()

        plt.subplot(121)
        plt.imshow(myImg*255)
        plt.subplot(122) 
        plt.imshow(myImg)
        #plt.colorbar()
        plt.show()

# %%
# %store myImgs
# %store myTargets
# Out:
# Stored 'myImgs' (ndarray)
# Stored 'myTargets' (ndarray)

# %%
import pandas as pd

# %%
# Save the resized data and labels
np.save('./toyData/toyTgts.npy',myTargets)
np.save('./toyData/toyImgs.npy',myImgs)

# %%
# Out:
# array([ 0.])
